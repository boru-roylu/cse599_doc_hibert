# %%
import csv
import functools
import gc
import json
import os
import sys

import copy
import copydf
import datasets
import decouple
import einops
import numpy as np
import pandas as pd
from sklearn.metrics import pairwise_distances
import transformers as tfs
import torch
import tqdm

import data_collator
import modeling_bert
import semscholar_data_process
import utils

# %% [markdown]
# ## Get data

# %%
# tried to import from semscholar_data_process.py but didn't work

def parse_metadata(metadata_path):

    paper_metadata = {}
    with open(metadata_path, 'r') as rf:
        for line in rf:
            raw_metadata = json.loads(line)
            paper_metadata[raw_metadata['paper_id']] = {
                k: v for k, v in raw_metadata.items() if k!='paper_id'
            }
            
    return paper_metadata

# %%
def build_paperstring(metadata, paper_id):

    title = metadata[paper_id]['title']
    authors = ', '.join([f'{author["first"]} {author["last"]}' for author in metadata[paper_id]['authors']])
    year = metadata[paper_id]['year']
    paperstring = f'{title}, by {authors} ({year}).'

    return paperstring

# %%
data_file = './project_dir/cse599/data/semscholar_data.jsonl'
metadata_file = './project_dir/cse599/data/semscholar_metadata.jsonl'
# out_file = 'preprocessed_data.jsonl'
# abstract_out_file = 'preprocessed_abstracts.jsonl'
embedding_size = 768

paper_data = []
with open(data_file, 'r') as rf:
    for line in rf:
        this_paper_data = json.loads(line)
        paper_data.append(this_paper_data)

metadata = parse_metadata(metadata_file)

print(f'paper_data: {len(paper_data)}')
papers = []
abstracts = []
paper_ids = []
for paper in paper_data:
    if paper['body_text'] and paper['abstract']:
        paper_sections = []
        for section_dict in paper['body_text']:
            paper_section = {
                'party': str(section_dict['section']),
                'text': str(semscholar_data_process.clean_text(section_dict['text'])),
            }
            # section = clean_text(section_dict['section'] + ' ' + section_dict['text'])
            paper_sections.append(paper_section)
        papers.append(paper_sections)

        abstract = {
            'party': 'abstract',
            'text': str(semscholar_data_process.clean_text(paper['abstract'][0]['text'])),
        }
        abstracts.append([abstract])
        # print(papers)

        paper_ids.append(paper['paper_id'])
# Out:
# paper_data: 203

# %%
len(papers)
# Out:
# 78

# %%
paper_num_sections = [len(paper) for paper in papers]
print(sum(paper_num_sections))
# Out:
# 2942

# %% [markdown]
# ## get embeddings

# %%
specter_emb_dir = '/g/tial/data/ccu/roylu/cse599/bert/embs/'
specter_emb_name = 'bert_mean_pooler_output'

hibert_emb_dir = '/g/tial/data/ccu/roylu/cse599/hibert/embs'
hibert_emb_name = 'conversation_pooler_output'

# %%
specter_output = utils.load_embeddings(specter_emb_dir, 'train')[specter_emb_name]
hibert_output = utils.load_embeddings(hibert_emb_dir, 'train')[hibert_emb_name]

# %%
specter_output.shape
# Out:
# (78, 768)

# %%
hibert_output.shape
# curr_start = 0
# hibert_output_meanpooled = []
# for num_sections in paper_num_sections:
#     paper_meanpooled_embed = np.mean(hibert_output[curr_start : curr_start + num_sections], axis=0)
#     hibert_output_meanpooled.append(paper_meanpooled_embed)
#     print(f'original shape ({hibert_output[curr_start : curr_start + num_sections].shape}) from {curr_start}')
#     curr_start += num_sections
#     print(f'new shape {paper_meanpooled_embed.shape}')
# hibert_output_meanpooled = np.stack(hibert_output_meanpooled, axis=0)
# print(f'final shape {hibert_output_meanpooled.shape}')
# Out:
# (78, 300)

# %%
def get_top5_neighbors(embeddings):

    distances = pairwise_distances(embeddings, metric='cosine')
    top5_lists = []
    top5_distances = []
    for embed_distances in distances:
        embed_ranks = embed_distances.argsort()
        embed_top5_neighbors = list(embed_ranks[1:6])
        embed_top5_distances = [embed_distances[neighbor_idx] for neighbor_idx in embed_top5_neighbors]

        top5_lists.append(embed_top5_neighbors)
        top5_distances.append(embed_top5_distances)
    
    return top5_lists, top5_distances

def get_intersections(a_top5_neighbors, b_top5_neighbors):

    intersections = []
    for a, b in zip(a_top5_neighbors, b_top5_neighbors):
        intersection = list(set(a) & set(b))
        intersections.append(intersection)

    return intersections

# %%
specter_top5_neighbors, specter_top5_distances = get_top5_neighbors(specter_output)
print(specter_top5_neighbors)
print(specter_top5_distances)

hibert_top5_neighbors, hibert_top5_distances = get_top5_neighbors(hibert_output)
print(hibert_top5_neighbors)
print(hibert_top5_distances)
# Out:
# [[7, 24, 51, 55, 54], [13, 64, 51, 49, 36], [38, 50, 58, 68, 5], [8, 53, 12, 67, 17], [70, 65, 63, 16, 52], [38, 50, 2, 58, 68], [57, 55, 76, 40, 14], [33, 24, 0, 22, 44], [62, 12, 3, 67, 17], [38, 2, 50, 58, 68], [23, 33, 41, 40, 76], [66, 42, 64, 49, 30], [17, 8, 66, 69, 3], [1, 36, 54, 49, 64], [40, 15, 62, 70, 33], [14, 40, 49, 70, 61], [52, 8, 47, 17, 27], [66, 12, 67, 69, 29], [46, 36, 48, 13, 54], [76, 55, 44, 48, 31], [73, 29, 65, 67, 63], [16, 76, 48, 31, 49], [48, 7, 24, 19, 76], [33, 44, 55, 10, 40], [7, 51, 54, 0, 22], [37, 5, 60, 50, 58], [56, 48, 76, 22, 32], [40, 3, 41, 30, 8], [53, 3, 27, 8, 49], [73, 20, 66, 17, 67], [70, 69, 66, 64, 42], [49, 48, 8, 30, 40], [39, 46, 31, 13, 63], [23, 40, 55, 49, 14], [70, 62, 40, 61, 65], [56, 70, 17, 4, 63], [13, 54, 23, 49, 18], [25, 60, 5, 50, 58], [50, 2, 58, 68, 5], [32, 48, 4, 35, 67], [33, 14, 27, 61, 76], [27, 8, 54, 40, 48], [49, 30, 74, 47, 66], [33, 44, 23, 70, 47], [23, 33, 43, 55, 19], [40, 3, 41, 23, 70], [32, 52, 18, 57, 63], [70, 17, 66, 30, 12], [76, 31, 40, 49, 54], [53, 40, 42, 30, 31], [38, 2, 58, 68, 5], [24, 0, 43, 13, 36], [64, 66, 16, 70, 47], [3, 49, 17, 28, 12], [36, 48, 13, 41, 49], [23, 33, 8, 76, 40], [26, 35, 76, 70, 31], [30, 6, 31, 70, 49], [38, 50, 2, 68, 5], [57, 53, 17, 49, 33], [5, 38, 50, 2, 58], [76, 70, 65, 72, 40], [8, 67, 12, 29, 17], [65, 70, 66, 17, 64], [66, 67, 52, 63, 17], [63, 20, 61, 72, 17], [17, 64, 12, 29, 63], [64, 17, 62, 20, 29], [38, 50, 2, 58, 5], [70, 12, 17, 63, 66], [69, 61, 63, 30, 47], [72, 61, 65, 63, 70], [71, 70, 61, 65, 63], [29, 20, 65, 67, 63], [66, 3, 42, 29, 17], [56, 35, 26, 76, 70], [61, 48, 40, 62, 55], [70, 61, 14, 62, 30]]
# [61, 70, 71]
# [17, 67, 20]
# [17, 66, 3, 42]
# [32, 26]
# [61, 55]
# [61]

# %%
metadata
# Out:
# {'77490025': {'title': 'State of external ocular muscles in strabismus of different duration',
#   'authors': [{'first': "Pen'kov", 'middle': [], 'last': 'Ma', 'suffix': ''},
#    {'first': 'Konstantinovskaia', 'middle': [], 'last': 'Ke', 'suffix': ''},
#    {'first': 'Zhukova', 'middle': [], 'last': 'Sv', 'suffix': ''}],
#   'abstract': None,
#   'year': 1975,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Oftalmologicheskiĭ zhurnal',
#   'mag_id': '2426173123',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77490025'},
#  '77490084': {'title': 'Management of uterine fibromyoma',
#   'authors': [{'first': 'Landau', 'middle': [], 'last': 'IaM', 'suffix': ''},
#    {'first': 'Karpushin', 'middle': [], 'last': 'Vp', 'suffix': ''}],
#   'abstract': None,
#   'year': 1972,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': None,
#   'mag_id': '2425602342',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77490084'},
#  '77490191': {'title': 'Nature of the reflex excitation of the spinal motor neurons in children with isiopathic scoliosis',
#   'authors': [{'first': 'Popov', 'middle': [], 'last': 'Sv', 'suffix': ''},
#    {'first': 'Gaĭvoronskiĭ', 'middle': [], 'last': 'Gi', 'suffix': ''}],
#   'abstract': None,
#   'year': 1977,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Zhurnal Nevropatologii I Psikhiatrii Imeni S S Korsakova',
#   'mag_id': '2437424934',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77490191'},
#  '77490289': {'title': "[Radioimmunoassay of serum gastrin and its preliminary clinical application (author's transl)].",
#   'authors': [{'first': 'Jin', 'middle': [], 'last': 'Js', 'suffix': ''}],
#   'abstract': None,
#   'year': 1980,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Chinese journal of internal medicine',
#   'mag_id': '2430030388',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77490289'},
#  '77490322': {'title': 'Sodium amytal in treatment of anxiety states; a preliminary report.',
#   'authors': [{'first': 'Cline', 'middle': [], 'last': 'Wb', 'suffix': ''}],
#   'abstract': None,
#   'year': 1952,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Diseases of the nervous system',
#   'mag_id': '2437852910',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77490322'},
#  '77490340': {'title': 'The neurosurgeon and neurotrauma care system design.',
#   'authors': [{'first': 'Pitts', 'middle': [], 'last': 'Lh', 'suffix': ''}],
#   'abstract': None,
#   'year': 1988,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Clinical neurosurgery',
#   'mag_id': '2437994786',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77490340'},
#  '77490349': {'title': 'Chronic pancreatitis and recurrent abdominal pain in childhood.',
#   'authors': [{'first': 'Househam', 'middle': [], 'last': 'Kc', 'suffix': ''}],
#   'abstract': None,
#   'year': 1987,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'South African Medical Journal',
#   'mag_id': '2434626620',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77490349'},
#  '77490515': {'title': '["Slow" or "rapid" tonsillectomy in rheumatic fever of tonsillar origin, in childhood?].',
#   'authors': [{'first': 'E', 'middle': [], 'last': 'DiLauro', 'suffix': ''}],
#   'abstract': None,
#   'year': 1966,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Annali di laringologia, otologia, rinologia, faringologia',
#   'mag_id': '2430607326',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77490515'},
#  '77490720': {'title': 'Fitness and longevity.',
#   'authors': [{'first': 'Baker', 'middle': [], 'last': 'Ra', 'suffix': ''}],
#   'abstract': None,
#   'year': 1983,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'American Family Physician',
#   'mag_id': '2419489932',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77490720'},
#  '77490837': {'title': '["Is there a physician on board?" The hit list of medical emergencies on board airplanes]',
#   'authors': [{'first': 'Füessl', 'middle': [], 'last': 'Hs', 'suffix': ''}],
#   'abstract': None,
#   'year': 2001,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Mmw-fortschritte Der Medizin',
#   'mag_id': '2419623995',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77490837'},
#  '77490849': {'title': 'A giant lipoma of the spermatic cord',
#   'authors': [{'first': 'Orlov', 'middle': [], 'last': 'Va', 'suffix': ''},
#    {'first': 'Shilov', 'middle': [], 'last': 'Ap', 'suffix': ''},
#    {'first': 'Ivanov', 'middle': [], 'last': 'Ae', 'suffix': ''}],
#   'abstract': None,
#   'year': 1988,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Khirurgii︠a︡',
#   'mag_id': '2426540513',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77490849'},
#  '77490871': {'title': 'SWELLING OF THE ARM AFTER RADICAL MASTECTOMY.',
#   'authors': [{'first': 'Britton', 'middle': [], 'last': 'Rc', 'suffix': ''}],
#   'abstract': None,
#   'year': 1964,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Medical record and annals',
#   'mag_id': '2428405769',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': ['11922467', '32995889', '22586239'],
#   'has_outbound_citations': False,
#   'has_inbound_citations': True,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77490871'},
#  '77491094': {'title': 'Histophysiological characteristics of small pulmonary arteries in newborn rats after experimental asphyxia',
#   'authors': [{'first': 'Markin', 'middle': [], 'last': 'Lb', 'suffix': ''}],
#   'abstract': None,
#   'year': 1975,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': "Eksperimental'naia khirurgiia i anesteziologiia",
#   'mag_id': '2427696682',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77491094'},
#  '77491174': {'title': "State rehabilitation administrators' views on psychological evaluation: a five-year follow-up study.",
#   'authors': [{'first': 'Cull', 'middle': [], 'last': 'Jg', 'suffix': ''},
#    {'first': 'Levinson', 'middle': [], 'last': 'Kf', 'suffix': ''}],
#   'abstract': None,
#   'year': 1977,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Rehabilitation literature',
#   'mag_id': '2433157376',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77491174'},
#  '77491215': {'title': '[Prof. Friedrich Pauwels (23 May 1885 - 19 January 1980)].',
#   'authors': [{'first': 'Plamenac', 'middle': [], 'last': 'Sd', 'suffix': ''}],
#   'abstract': None,
#   'year': 1980,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Srpski Arhiv Za Celokupno Lekarstvo',
#   'mag_id': '2438533601',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77491215'},
#  '77491274': {'title': 'Social differences in growth and maturation',
#   'authors': [{'first': 'Jürgens', 'middle': [], 'last': 'Hw', 'suffix': ''}],
#   'abstract': None,
#   'year': 1971,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Monatsschrift Kinderheilkunde',
#   'mag_id': '2431192043',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77491274'},
#  '77491423': {'title': '[Care of tuberculosis patients at the community level in the state of Chiapas, Mexico].',
#   'authors': [{'first': 'Solórzano',
#     'middle': ['Moguel'],
#     'last': 'Jj',
#     'suffix': ''},
#    {'first': 'Alvarez', 'middle': ['Cuevas'], 'last': 'Me', 'suffix': ''}],
#   'abstract': None,
#   'year': 1991,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Boletín de la Oficina Sanitaria Panamericana. Pan American Sanitary Bureau',
#   'mag_id': '2429362883',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77491423'},
#  '77491534': {'title': 'Incidence of liver disease in carriers of hepatitis B antigen',
#   'authors': [{'first': 'J',
#     'middle': [],
#     'last': 'RodenasCerda',
#     'suffix': ''},
#    {'first': 'A', 'middle': [], 'last': 'RubioBaget', 'suffix': ''},
#    {'first': 'R', 'middle': [], 'last': 'SansBotargues', 'suffix': ''}],
#   'abstract': None,
#   'year': 1977,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Revista española de las enfermedades del aparato digestivo',
#   'mag_id': '2430012781',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77491534'},
#  '77491577': {'title': 'Use of cadaver blood in the treatment of thromboembolic diseases',
#   'authors': [{'first': 'Zykova', 'middle': [], 'last': 'Ki', 'suffix': ''}],
#   'abstract': None,
#   'year': 1969,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Voenno-medit︠s︡inskiĭ zhurnal',
#   'mag_id': '2429446581',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77491577'},
#  '77491863': {'title': 'Pathogenesis and treatment of neurological disorders in patients with endometriosis',
#   'authors': [{'first': 'Akimov', 'middle': [], 'last': 'Ga', 'suffix': ''},
#    {'first': 'Baskakov', 'middle': [], 'last': 'Vp', 'suffix': ''},
#    {'first': 'Videnin', 'middle': [], 'last': 'Vs', 'suffix': ''},
#    {'first': "Gur'ev", 'middle': [], 'last': 'Av', 'suffix': ''},
#    {'first': 'Tsvelev', 'middle': [], 'last': 'IuV', 'suffix': ''}],
#   'abstract': None,
#   'year': 1979,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Vrachebnoe delo',
#   'mag_id': '2418053549',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77491863'},
#  '77491866': {'title': 'Peripheral blood monocytosis as an early symptom of acute leukemia with 1st manifestations of cytopenia',
#   'authors': [{'first': 'Iavorkovskiĭ',
#     'middle': [],
#     'last': 'Li',
#     'suffix': ''},
#    {'first': 'Soloveĭ', 'middle': [], 'last': 'DIa', 'suffix': ''},
#    {'first': 'Riauzova', 'middle': [], 'last': 'LIu', 'suffix': ''},
#    {'first': 'Udris', 'middle': [], 'last': 'OIu', 'suffix': ''}],
#   'abstract': None,
#   'year': 1982,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Terapevticheskii Arkhiv',
#   'mag_id': '2431146085',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77491866'},
#  '77491955': {'title': '[Conservative surgery of renal carcinoma in a case of synchronic bilateral involvement, with large size tumors and different histological type].',
#   'authors': [{'first': 'Gallo',
#     'middle': ['Rolanía'],
#     'last': 'Fj',
#     'suffix': ''}],
#   'abstract': 'OBJECTIVE: To report a case of a large, bilateral, synchronous renal tumor. METHODS/RESULTS: Treatment by conservative surgery achieved good results. The histological analysis showed two different carcinomas. The most most important steps of the surgical procedure are described. Renal preservation in patients with malignant tumors is discussed. CONCLUSIONS: The case described herein is rare since the tumors were synchronous and of uncommon histological type (one of the tumors was a chromophobic carcinoma). Despite the large size of the tumors, they were successfully managed by conservative surgery.',
#   'year': 2000,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Archivos españoles de urología',
#   'mag_id': '2422983478',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77491955'},
#  '77491964': {'title': 'The nurse and hazardous waste',
#   'authors': [{'first': 'Cayla', 'middle': [], 'last': 'Js', 'suffix': ''}],
#   'abstract': None,
#   'year': 1991,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Soins; la revue de référence infirmière',
#   'mag_id': '2428806980',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77491964'},
#  '77492035': {'title': 'Gunshot wound of the heart and right lung in a patient with a mitral defect',
#   'authors': [{'first': 'Sokolov', 'middle': [], 'last': 'Ea', 'suffix': ''},
#    {'first': 'Sadovnikov', 'middle': [], 'last': 'Aa', 'suffix': ''}],
#   'abstract': None,
#   'year': 1974,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Vestnik khirurgii imeni I. I. Grekova',
#   'mag_id': '2423218090',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77492035'},
#  '77492214': {'title': 'Birth control decision',
#   'authors': [{'first': 'Moore', 'middle': [], 'last': 'Jl', 'suffix': ''}],
#   'abstract': None,
#   'year': 1965,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Journal of the Medical Association of Georgia',
#   'mag_id': '2442768377',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77492214'},
#  '77492325': {'title': 'Practicing medicine in the year 2000.',
#   'authors': [{'first': 'Fox', 'middle': [], 'last': 'Pd', 'suffix': ''}],
#   'abstract': None,
#   'year': 1986,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Der Internist',
#   'mag_id': '2424826941',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77492325'},
#  '77492438': {'title': 'What should I consider in establishing a component dental ethics committee',
#   'authors': [{'first': 'Fontana', 'middle': [], 'last': 'Na', 'suffix': ''}],
#   'abstract': None,
#   'year': 2008,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Journal of the American Dental Association',
#   'mag_id': '2433121685',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77492438'},
#  '77492504': {'title': '[HEALTH CONDITIONS IN THE AMERICAS, 1961-1962].',
#   'authors': [{'first': 'Ross', 'middle': [], 'last': 'Jd', 'suffix': ''}],
#   'abstract': None,
#   'year': 1965,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Boletín de la Oficina Sanitaria Panamericana. Pan American Sanitary Bureau',
#   'mag_id': '2436838081',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77492504'},
#  '77492582': {'title': 'Classification of laryngeal carcinoma.',
#   'authors': [{'first': 'Shepperd', 'middle': [], 'last': 'Hw', 'suffix': ''}],
#   'abstract': None,
#   'year': 1974,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Canadian journal of otolaryngology',
#   'mag_id': '2437191707',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77492582'},
#  '77492598': {'title': '[Use of coomassie Brilliant Blue G-250 in photometric protein determination].',
#   'authors': [{'first': 'Mamedov', 'middle': [], 'last': 'Mk', 'suffix': ''},
#    {'first': 'Abdullaev', 'middle': [], 'last': 'Mn', 'suffix': ''}],
#   'abstract': None,
#   'year': 1987,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Laboratornoe delo',
#   'mag_id': '2437820344',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77492598'},
#  '77492599': {'title': 'Immediate loading of implants: an improved treatment for the elderly.',
#   'authors': [{'first': 'Vassos', 'middle': [], 'last': 'Dm', 'suffix': ''}],
#   'abstract': None,
#   'year': 1996,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Dental implantology update',
#   'mag_id': '2441141134',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77492599'},
#  '77492789': {'title': '[Radionuclide-thermographic diagnosis of neck paragangliomas].',
#   'authors': [{'first': 'Gabuniia', 'middle': [], 'last': 'Ri', 'suffix': ''},
#    {'first': 'Dzhumaev', 'middle': [], 'last': 'Mg', 'suffix': ''},
#    {'first': 'Lenskaia', 'middle': [], 'last': 'Op', 'suffix': ''},
#    {'first': 'Bagdasarov', 'middle': [], 'last': 'IuV', 'suffix': ''}],
#   'abstract': None,
#   'year': 1985,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Meditsinskaia radiologiia',
#   'mag_id': '2434358550',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77492789'},
#  '77492792': {'title': 'Health status of persons who participated in the elimination of consequences of the Chernobyl AES accident',
#   'authors': [{'first': 'Khomaziuk',
#     'middle': [],
#     'last': 'In',
#     'suffix': ''}],
#   'abstract': None,
#   'year': 1991,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Vestnik Akademii meditsinskikh nauk SSSR',
#   'mag_id': '2433183597',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77492792'},
#  '77492800': {'title': 'Hypertensive heart disease.',
#   'authors': [{'first': 'Murphy', 'middle': [], 'last': 'Fd', 'suffix': ''}],
#   'abstract': None,
#   'year': 1947,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Journal - Michigan State Medical Society',
#   'mag_id': '2434259459',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77492800'},
#  '77492841': {'title': 'Assessing the quality of teaching.',
#   'authors': [{'first': 'Speer', 'middle': [], 'last': 'Aj', 'suffix': ''},
#    {'first': 'Elnicki', 'middle': [], 'last': 'Dm', 'suffix': ''}],
#   'abstract': None,
#   'year': 1999,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'The American Journal of Medicine',
#   'mag_id': '2461250092',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77492841'},
#  '77492970': {'title': 'When are we going to retire',
#   'authors': [{'first': 'Goedhard', 'middle': [], 'last': 'Wj', 'suffix': ''}],
#   'abstract': None,
#   'year': 1993,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Tijdschrift Voor Gerontologie En Geriatrie',
#   'mag_id': '2461175505',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77492970'},
#  '77493062': {'title': 'Neuritis ossificans with osteogenic sarcoma in brachial plexus following trauma; report of case.',
#   'authors': [{'first': 'Woltman', 'middle': [], 'last': 'Hw', 'suffix': ''},
#    {'first': 'Adson', 'middle': [], 'last': 'Aw', 'suffix': ''}],
#   'abstract': None,
#   'year': 1946,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'The Journal-lancet',
#   'mag_id': '2425403859',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77493062'},
#  '77493076': {'title': 'Letter: Risk factors after coronary thrombosis.',
#   'authors': [{'first': 'Burch', 'middle': [], 'last': 'Pr', 'suffix': ''}],
#   'abstract': None,
#   'year': 1975,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'The Lancet',
#   'mag_id': '2433863249',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77493076'},
#  '77493177': {'title': 'Effects of Acute Exercise on Plasma Apelin and Blood Glucose in Healthy Young Subjects: 307 Board #158 May 27, 11',
#   'authors': [{'first': 'Allan',
#     'middle': ['H.'],
#     'last': 'Goldfarb',
#     'suffix': ''},
#    {'first': 'Justin', 'middle': ['D.'], 'last': 'Waller', 'suffix': ''},
#    {'first': 'Emily', 'middle': ['H.'], 'last': 'McNeill', 'suffix': ''},
#    {'first': 'Frank', 'middle': ['Y.'], 'last': 'Zhong', 'suffix': ''},
#    {'first': 'Lauren', 'middle': ['S.'], 'last': 'Vervaecke', 'suffix': ''}],
#   'abstract': None,
#   'year': 2015,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': '10.1249/01.mss.0000476605.29629.3a',
#   'venue': None,
#   'journal': 'Medicine and Science in Sports and Exercise',
#   'mag_id': '2461370920',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77493177'},
#  '77493189': {'title': 'Induction of bone tissue regeneration in dogs in the area of a skull defect following a heterotransplant of fresh or lyophilized bone filings.',
#   'authors': [{'first': 'Kantorova', 'middle': [], 'last': 'Vi', 'suffix': ''},
#    {'first': 'Zhukova', 'middle': [], 'last': 'Gn', 'suffix': ''}],
#   'abstract': None,
#   'year': 1971,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'The Soviet journal of developmental biology',
#   'mag_id': '2461856779',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77493189'},
#  '77493227': {'title': 'LibGuides: Medicine (HYMS): Finding Resources',
#   'authors': [{'first': 'Hyms',
#     'middle': ['Library'],
#     'last': 'Team',
#     'suffix': ''}],
#   'abstract': None,
#   'year': 2011,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': None,
#   'mag_id': '2461828990',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77493227'},
#  '77493266': {'title': 'Cholegraphy in opisthorchiasis',
#   'authors': [{'first': 'Pishchin', 'middle': [], 'last': 'Em', 'suffix': ''}],
#   'abstract': None,
#   'year': 1971,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Klinicheskaia meditsina',
#   'mag_id': '2460643746',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77493266'},
#  '77493269': {'title': 'The radiology corner. Pneumatosis coli.',
#   'authors': [{'first': 'Marshak', 'middle': [], 'last': 'Rh', 'suffix': ''},
#    {'first': 'Lindner', 'middle': [], 'last': 'Ae', 'suffix': ''},
#    {'first': 'Milano', 'middle': [], 'last': 'Am', 'suffix': ''}],
#   'abstract': None,
#   'year': 1971,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'The American Journal of Gastroenterology',
#   'mag_id': '2442337774',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77493269'},
#  '77493472': {'title': '종설 : 류코트리엔과 알레르기 염증',
#   'authors': [{'first': '', 'middle': [], 'last': '김상훈', 'suffix': ''},
#    {'first': '곹썕', 'middle': [], 'last': '源', 'suffix': ''}],
#   'abstract': 'Leukotrienes (LTs) are important lipid mediators involved in allergic inflammation. The LT pathway is relatively steroid- resistant, which suggests the possibility that its blockade by alternative means may facilitate asthma management. Cysteinyl LT receptor 1 antagonists are well accepted for their efficacy and safety in asthma management. Recent studies have revealed evolving findings indicating that leukotriene B4 has an important role in the development of asthma as well as in the potential importance of cysteinyl LTs in airway remodeling. These new findings provide important clues to achieve superior control of allergic inflammation. (Korean J Asthma Allergy Clin Immunol 2012;32:67-72)',
#   'year': 2012,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': None,
#   'mag_id': '2905718899,2462120585',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77493472'},
#  '77493547': {'title': 'Human growth as seen from the viewpoint of macroscopic morphology',
#   'authors': [{'first': 'Baumann', 'middle': [], 'last': 'Ja', 'suffix': ''}],
#   'abstract': None,
#   'year': 1953,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Schweizerische Medizinische Wochenschrift',
#   'mag_id': '2436040129',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77493547'},
#  '77493615': {'title': 'THE PERSISTENT CHALLENGE OF HYSTERECTOMY.',
#   'authors': [{'first': 'Israel', 'middle': [], 'last': 'Sl', 'suffix': ''}],
#   'abstract': None,
#   'year': 1965,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Southern Medical Journal',
#   'mag_id': '2428451652',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77493615'},
#  '77493656': {'title': '[Functional and histochemical changes in the pancreas in diseases and after surgery of the liver, gallbladder, stomach and pancreas. (Review of Russian and foreign literature)].',
#   'authors': [{'first': 'Volkova', 'middle': [], 'last': 'Lp', 'suffix': ''}],
#   'abstract': None,
#   'year': 1962,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Vestnik khirurgii imeni I. I. Grekova',
#   'mag_id': '2440614340',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77493656'},
#  '77493666': {'title': '[Scleroplasty using a corneo-scleral graft in school-age children th progressive myopia].',
#   'authors': [{'first': 'Vatchenko', 'middle': [], 'last': 'Aa', 'suffix': ''},
#    {'first': "Strogal'", 'middle': [], 'last': 'As', 'suffix': ''},
#    {'first': 'Khomich', 'middle': [], 'last': 'St', 'suffix': ''},
#    {'first': 'Riabykin', 'middle': [], 'last': 'Ng', 'suffix': ''},
#    {'first': 'Kukhtiak', 'middle': [], 'last': 'Bi', 'suffix': ''}],
#   'abstract': None,
#   'year': 1988,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Oftalmologicheskiĭ zhurnal',
#   'mag_id': '2418956118',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77493666'},
#  '77493906': {'title': 'INSTALLING A HOSPITAL INFORMATION SYSTEM',
#   'authors': [{'first': 'Tanser', 'middle': [], 'last': 'Ar', 'suffix': ''}],
#   'abstract': None,
#   'year': 1991,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'British Journal of Hospital Medicine',
#   'mag_id': '2462803806',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77493906'},
#  '77494140': {'title': '[Endometriosis, predisposition and prevention].',
#   'authors': [{'first': 'Berger', 'middle': [], 'last': 'Lw', 'suffix': ''},
#    {'first': 'Kroeks', 'middle': [], 'last': 'Mv', 'suffix': ''}],
#   'abstract': None,
#   'year': 1985,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Nederlands Tijdschrift voor Geneeskunde',
#   'mag_id': '2462909607',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77494140'},
#  '77494168': {'title': 'Circulation in the cranial sinuses',
#   'authors': [{'first': 'Belekhova',
#     'middle': [],
#     'last': 'Mg',
#     'suffix': ''}],
#   'abstract': None,
#   'year': 1958,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Fiziologicheskiĭ zhurnal',
#   'mag_id': '2429373488',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77494168'},
#  '77494170': {'title': 'Relato de caso: técnica tumescente em bovino para realização de desvio lateral do pênis',
#   'authors': [{'first': 'A.',
#     'middle': ['P.', 'A.'],
#     'last': 'Mendonça',
#     'suffix': ''},
#    {'first': 'T.', 'middle': ['S.', 'M.', 'e'], 'last': 'Silva', 'suffix': ''},
#    {'first': 'V.', 'middle': ['B.'], 'last': 'Castro', 'suffix': ''},
#    {'first': 'J.', 'middle': ['H.'], 'last': 'Perotta', 'suffix': ''}],
#   'abstract': 'A NDB bull weighing 350kg underwent a ruffian preparation by penis lateral deviation technique at the Veterinary Hospital of the University UFRB. As premedication (MPA), 2% xylazine (0.05 mg/kg) was administered intramuscularly and a tumescent solution was used for local anesthesia. Approximately 10 minutes after administration of MPA, the animal was removed from the trunk and placed in the right lateral decubitus position, with subsequent trichotomy and antisepsis of the region to be surgically treated. The anesthetic solution consisted of 500 mL Ringer lactate, 1 mg epinephrine and 20 mL 2% lidocaine without vasoconstrictor. The entire solution was administered in the subcutaneous tissue by infiltrative technique, covering the area to be incised. After the anesthetic blockage around the foreskin and penis attachment site, the incision of the skin and subcutaneous tissue was performed. Approximately 0.5 cm of skin was removed from the new site to be implanted at a 45° angle, and the skin was sutured with Wolff stitches of non-absorbable material. The Tumescent Anesthetic Technique (TAT) was performed successfully since the animal had a good recovery without adverse effects. As described in the literature, the incised areas showed a tiny amount of bleeding. Its analgesic effect could also be observed postoperatively by the animal behavior and ease when cleaning the wound. The physiological parameters (HR 58 ± 2 and f 22 ± 4) were within normal limits for the species at surgery, remaining constant until the end of the procedure. It is possible that TAT could become an anesthetic technique widely used in cattle, since it is efficient, promotes analgesia and local anesthesia of large areas, it is easy to use and low cost.',
#   'year': 2015,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': None,
#   'mag_id': '2419196022',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77494170'},
#  '77494393': {'title': 'Treatment of hepatozoon in dogs by primaquine dihydrophosphate',
#   'authors': [{'first': 'Suwanni',
#     'middle': [],
#     'last': 'Nithi-uthai',
#     'suffix': ''},
#    {'first': 'Songkhram',
#     'middle': [],
#     'last': 'Luangthongkham',
#     'suffix': ''}],
#   'abstract': None,
#   'year': 1999,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': None,
#   'mag_id': '2434684345',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77494393'},
#  '77494666': {'title': '[Dispersion method for determining recurrence of circadian curves of excretion of urine, sodium and potassium].',
#   'authors': [{'first': 'Aslanian', 'middle': [], 'last': 'Nl', 'suffix': ''},
#    {'first': 'Shukhian', 'middle': [], 'last': 'Vm', 'suffix': ''},
#    {'first': 'Krishian', 'middle': [], 'last': 'Em', 'suffix': ''},
#    {'first': 'Babaian', 'middle': [], 'last': 'La', 'suffix': ''},
#    {'first': 'Airapetian', 'middle': [], 'last': 'La', 'suffix': ''}],
#   'abstract': None,
#   'year': 1984,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Laboratornoe delo',
#   'mag_id': '2463793111',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77494666'},
#  '77494904': {'title': 'Orientation of the postero-anterior skull cephalogram by registration on mathematical centers.',
#   'authors': [{'first': 'Yousif', 'middle': [], 'last': 'Ma', 'suffix': ''}],
#   'abstract': None,
#   'year': 1986,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': None,
#   'mag_id': '2437718634',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77494904'},
#  '77495000': {'title': 'Diagnosis of syphilis before the appearance of primary chancre',
#   'authors': [{'first': 'Eckes', 'middle': [], 'last': 'Lk', 'suffix': ''}],
#   'abstract': None,
#   'year': 1951,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Dermatologische Wochenschrift',
#   'mag_id': '2440304827',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77495000'},
#  '77495056': {'title': '[A patient with acute tubular necrosis as a consequence of drinking diethylene glycol-treated wine].',
#   'authors': [{'first': 'R', 'middle': [], 'last': 'vanLeusen', 'suffix': ''},
#    {'first': 'Uges', 'middle': [], 'last': 'Dr', 'suffix': ''}],
#   'abstract': None,
#   'year': 1987,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Nederlands Tijdschrift voor Geneeskunde',
#   'mag_id': '2460930164',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77495056'},
#  '77495099': {'title': 'Long-Acting Reversible Contraceptives and Adolescents: Assessing Benefits and Overcoming Barriers.',
#   'authors': [{'first': 'McKnight', 'middle': [], 'last': 'Er', 'suffix': ''},
#    {'first': 'Berlan', 'middle': [], 'last': 'Ed', 'suffix': ''}],
#   'abstract': None,
#   'year': 2014,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': None,
#   'mag_id': '2439001667',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77495099'},
#  '77495155': {'title': 'Effektivität der manuellen Medizin in der HNO: Eine retrospektive Langzeituntersuchung',
#   'authors': [{'first': 'M.', 'middle': [], 'last': 'Hülse', 'suffix': ''},
#    {'first': 'M.', 'middle': [], 'last': 'Hölzl', 'suffix': ''}],
#   'abstract': 'Background. The vertebral genesis of many functional disorders in otorhinolaryngology, such as dizziness,hearing-impairment,ear-pressure, ear-pain,foreign body sensation in the throat and dysphonia, is suggested by the success of spinal manipulative therapy, particularly of the atlanto-occipital joint. Up to now,there are no retrospective investigations which show the duration of the therapeutic effect. Methods. We examined 220 patients with cervical otorhinolaryngological disorders (100 patients with dizziness, 49 with hearing impairment,47 with tinnitus and 24 with dysphonia) after cervical manipulation lasting more than 6 months. Results and conclusions. The extraordinary satisfaction with the manipulative therapy in 82% of patients with dizziness (46% total relief, 36% high improvement) reflects the high efficiency of this manual therapy. In contrast to these results, only 10% of patients with tinnitus showed an improvement (P<0.001).This retrospective investigation demonstrates that a successful outcome after manual therapy is not based on a placebo effect.',
#   'year': 2004,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': None,
#   'mag_id': '2464501975',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77495155'},
#  '77495195': {'title': 'Superstition and medical knowledge in an Italian herbal.',
#   'authors': [{'first': 'Silberman',
#     'middle': [],
#     'last': 'Hc',
#     'suffix': ''}],
#   'abstract': None,
#   'year': 1996,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'Pharmacy in history',
#   'mag_id': '2465063576',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77495195'},
#  '77495206': {'title': 'Congenital choanal occlusion.',
#   'authors': [{'first': 'Mahoney', 'middle': [], 'last': 'Pl', 'suffix': ''}],
#   'abstract': None,
#   'year': 1949,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': 'The Journal of the Arkansas Medical Society',
#   'mag_id': '2430758743',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77495206'},
#  '77495361': {'title': 'HEALTH CARE FINANCING ADMINISTRATION',
#   'authors': [{'first': 'Haworth',
#     'middle': [],
#     'last': 'Editorial Submission',
#     'suffix': ''}],
#   'abstract': None,
#   'year': 2000,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': '10.1300/J138v04n01_15',
#   'venue': None,
#   'journal': 'Health Care on the Internet archive',
#   'mag_id': '2464637723',
#   'mag_field_of_study': ['Medicine'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:77495361'},
#  '77495918': {'title': 'Trace element issues in Switzerland and Europe',
#   'authors': [{'first': 'Berger', 'middle': [], 'last': 'Mm', 'suffix': ''}],
#   'abstract': None,
#   'year': 2012,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
# ...
#   'year': 2011,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': '10.1007/978-3-642-21783-8_47',
#   'venue': 'Communications in Computer and Information Science',
#   'journal': 'Communications in Computer and Information Science',
#   'mag_id': '2238684384',
#   'mag_field_of_study': ['Computer Science'],
#   'outbound_citations': [],
#   'inbound_citations': ['53439444', '53434638'],
#   'has_outbound_citations': False,
#   'has_inbound_citations': True,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:123625307'},
#  '123625503': {'title': 'Stretchable and compressible thin films of stiff materials on compliant wavy substrates',
#   'authors': [{'first': 'J.', 'middle': [], 'last': 'Xiao', 'suffix': ''},
#    {'first': 'A.', 'middle': [], 'last': 'Carlson', 'suffix': ''},
#    {'first': 'Z. J.', 'middle': [], 'last': 'Liu', 'suffix': ''},
#    {'first': 'Y.', 'middle': [], 'last': 'Huang', 'suffix': ''},
#    {'first': 'H.', 'middle': [], 'last': 'Jiang', 'suffix': ''},
#    {'first': 'J. A.', 'middle': [], 'last': 'Rogers', 'suffix': ''}],
#   'abstract': 'This letter presents experimental, numerical, and analytical studies of Au thin films on elastomeric substrates of poly(dimethylsiloxane) that are designed with sinusoidal, “wavy” features of surface relief. Such systems can be useful as stretchable conductors in electronic or sensory devices. The maximum film strain is obtained in terms of film and substrate elastic moduli, film thickness, amplitude and wavelength of the wavy profile, and the applied strain. These analytical solutions agree well with both finite element analysis and experimentally measured changes in the sinusoidal profile under small, uniaxial strains. A simple expression for the system stretchability and compressibility is established.',
#   'year': 2008,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': '10.1063/1.2955829',
#   'venue': None,
#   'journal': 'Applied Physics Letters',
#   'has_pdf_body_text': False,
#   'mag_id': '2080426631',
#   'mag_field_of_study': ['Physics'],
#   'outbound_citations': ['4408472'],
#   'inbound_citations': ['3634067',
#    '171092881',
#    '54104795',
#    '53019766',
#    '27248561',
#    '214941886',
#    '4857250',
#    '14584143',
#    '14469418',
#    '55257231',
#    '115287229',
#    '831622',
#    '16211452',
#    '21750422',
#    '14541905',
#    '42113621',
#    '215057889',
#    '5217693',
#    '138205035',
#    '137307817',
#    '51833812',
#    '125536206'],
#   'has_outbound_citations': True,
#   'has_inbound_citations': True,
#   'has_pdf_parse': True,
#   'has_pdf_parsed_abstract': False,
#   'has_pdf_parsed_body_text': False,
#   'has_pdf_parsed_bib_entries': True,
#   'has_pdf_parsed_ref_entries': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:123625503'},
#  '123625563': {'title': 'Approximations of discrete time partially observed control problems',
#   'authors': [{'first': 'Wolfgang',
#     'middle': ['J.'],
#     'last': 'Runggaldier',
#     'suffix': ''},
#    {'first': 'Lukasz', 'middle': [], 'last': 'Stettner', 'suffix': ''}],
#   'abstract': None,
#   'year': 1994,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': None,
#   'has_pdf_body_text': False,
#   'mag_id': '2074407336',
#   'mag_field_of_study': ['Mathematics'],
#   'outbound_citations': [],
#   'inbound_citations': ['266219',
#    '17069925',
#    '116937019',
#    '21714843',
#    '5615816',
#    '123529549',
#    '1205102',
#    '59419724',
#    '14123733',
#    '3615795',
#    '19878419',
#    '122426919',
#    '30883103',
#    '207006924'],
#   'has_outbound_citations': False,
#   'has_inbound_citations': True,
#   'has_pdf_parse': True,
#   'has_pdf_parsed_abstract': False,
#   'has_pdf_parsed_body_text': False,
#   'has_pdf_parsed_bib_entries': False,
#   'has_pdf_parsed_ref_entries': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:123625563'},
#  '123625612': {'title': 'Theories of Multiple Equilibria-A Critical Reexamination. Part I: Barotropic Models',
#   'authors': [{'first': 'K.', 'middle': ['K.'], 'last': 'Tung', 'suffix': ''},
#    {'first': 'A.', 'middle': ['J.'], 'last': 'Rosenthal', 'suffix': ''}],
#   'abstract': 'Abstract Previous results claiming the existence of multiple equilibria based on simple barotropic or two-layer models of the atmosphere are reexamined. While not ruling out the existence of multiple equilibria we find that the application of these results to the atmosphere, especially with regard to high/low zonal index and zonal/blocked situations, is probably problematic. Results based on truncated low-order models are found to change drastically when full nonlinearity is retained. Although multiple equilibria may still exist in some nonlinear models in some restricted parameter regimes, it is argued that the parameter values adopted in previous studies are probably not physically based. Mathematically interesting properties of the nonlinear system, such as resonance bending, hysteresis, bifurcation and multiplicity of solutions are also discussed.',
#   'year': 1985,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': '10.1175/1520-0469(1985)042<2804:TOMEAC>2.0.CO;2',
#   'venue': None,
#   'journal': 'Journal of the Atmospheric Sciences',
#   'mag_id': '2075778488',
#   'mag_field_of_study': ['Physics'],
#   'outbound_citations': [],
#   'inbound_citations': ['17140735',
#    '122345764',
#    '439675',
#    '55593621',
#    '160003816',
#    '121799301',
#    '54668135',
#    '54941988',
#    '59440642',
#    '119442630',
#    '124178712',
#    '6695279',
#    '55931627',
#    '44237829',
#    '55995197',
#    '119440560',
#    '124078486',
#    '34903907',
#    '20876617',
#    '53519223'],
#   'has_outbound_citations': False,
#   'has_inbound_citations': True,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:123625612'},
#  '123625681': {'title': 'On Solution Existence and Applications of a Class of Nonmonotone Operator Equation',
#   'authors': [{'first': 'Zhang',
#     'middle': [],
#     'last': 'Chuan-lin',
#     'suffix': ''}],
#   'abstract': 'By using cone theorem and monotone iterative method, the mixed monotone condition in A(x,y)+Mx in Banach spaces is extended.The traditional mixed monotonicity is replaced by A(x,y)+Tx.Then the existence of solutions for a kind of nonmonotonic operator equation is given and the initial value problems for impulsive differential equations are discussed.',
#   'year': 2007,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': None,
#   'venue': None,
#   'journal': "Journal of Xi'an Technological University",
#   'mag_id': '2372939041',
#   'mag_field_of_study': ['Mathematics'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:123625681'},
#  '123625943': {'title': 'On the mechanism of polarized electroluminescence from light‐emitting structures based on GaN',
#   'authors': [{'first': 'Ya.',
#     'middle': ['D.'],
#     'last': 'Lebedev',
#     'suffix': ''},
#    {'first': 'M.', 'middle': ['V.'], 'last': 'Fok', 'suffix': ''},
#    {'first': 'M.', 'middle': ['D.'], 'last': 'Shagalov', 'suffix': ''}],
#   'abstract': 'Investigations of photoelectromotive force and photoconductivity are made in order to find the mechanism of electroluminescence in the GaN: (Zn, O) light-emitting structures. They enable to detect the existence of two channels of current flow in the structures investigated. One of them is a diode circuit with a potential barrier of ≈ 3 eV. This channel of conductivity is responsible for the unipolar electroluminescence with Emax ≈ 2.6 eV and with polarization degree up to ≈ 60%. The large value of the potential barrier height shows that gallium nitride may be of p-type conductivity. The analysis of the peculiarities of the growth and doping of GaN does not contradict this supposition. ::: ::: ::: ::: [Russian Text Ignored].',
#   'year': 1988,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': '10.1002/pssa.2211080223',
#   'venue': None,
#   'journal': 'Physica Status Solidi (a)',
#   'mag_id': '2078835945',
#   'mag_field_of_study': ['Physics'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:123625943'},
#  '123626373': {'title': 'The 6− analog-antianalog states of 28Si☆',
#   'authors': [{'first': 'G.', 'middle': ['F.'], 'last': 'Neal', 'suffix': ''},
#    {'first': 'S.', 'middle': ['T.'], 'last': 'Lam', 'suffix': ''}],
#   'abstract': 'Abstract A resonance is observed in the 27 Al(p, γ) 28 Si reaction at E p =2876±2 keV, which corresponds to an excitation energy of 14356±2 keV. The 14.36 MeV level decays to a new level at 11577±2 keV, which is turn decays to the known level at 9701.8±0.5 keV. With previous information on the 9.70 MeV level and the present γ-ray angular distributions, obtained from singles spectra as recorded by a 40 cm 3 Ge(Li) detector, the spins of the three levels can be limited to J =5, 6; J =6; and J =5, respectively. Transition strength arguments based on measurements of the strength of the 2876 keV resonance and the lifetime of the 11.58 MeV level indicate that the 14.36 MeV level has J π =6 − , T =1 and that the 11.58 MeV level has J π =6 − , T =0.',
#   'year': 1973,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': '10.1016/0370-2693(73)90081-6',
#   'venue': None,
#   'journal': 'Physics Letters B',
#   'mag_id': '2071275768',
#   'mag_field_of_study': ['Physics'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:123626373'},
#  '123626434': {'title': 'Nonstationary photocurrent in a Bi12SiO20 crystal grown in an argon atmosphere',
#   'authors': [{'first': 'M.',
#     'middle': ['A.'],
#     'last': 'Bryushinin',
#     'suffix': ''},
#    {'first': 'I.', 'middle': ['A.'], 'last': 'Sokolov', 'suffix': ''}],
#   'abstract': 'A detailed investigation of the nonstationary photocurrent in crystals with a sillenite structure grown in an oxygen-free (argon) atmosphere is performed. Basic parameters of the photoinduced charge carriers in the crystals investigated, such as the mean carrier lifetime and mobility, the mean photoconductivity, the carrier diffusion length, and the Debye screening length, are determined.',
#   'year': 1999,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': '10.1134/1.1262484',
#   'venue': None,
#   'journal': 'Technical Physics Letters',
#   'mag_id': '2078482604',
#   'mag_field_of_study': ['Physics'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:123626434'},
#  '123626477': {'title': 'Unbounded quadrature domains inRn (n≥3)',
#   'authors': [{'first': 'Henrik',
#     'middle': [],
#     'last': 'Shahgholian',
#     'suffix': ''}],
#   'abstract': 'As a result of the powerful tools of complex analysis a lot of problems have been solved in the theory of Q.D.s (quadrature domain) inR2. These problems are almost untouched inRn (n≥3). To study Q.D.s. inRn, one has to supply the subject with new techniques. This is the goal of papers by Shapiro, Khavinson and Shapiro, Sakai, and Gustafsson, where the authors approach the subject inRn by different methods. The main purpose of this paper is to generalize some of the ideas (already known inR2) toRn (n≥3), and we merely work with unbounded Q.D.',
#   'year': 1991,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': '10.1007/BF02820468',
#   'venue': None,
#   'journal': 'Journal d’Analyse Mathématique',
#   'mag_id': '2084855174',
#   'mag_field_of_study': ['Mathematics'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:123626477'},
#  '123626539': {'title': 'Dynamic Analysis of Elastic Mechanism Systems. Part II: Experimental Results',
#   'authors': [{'first': 'D. A.', 'middle': [], 'last': 'Turcic', 'suffix': ''},
#    {'first': 'Ashok', 'middle': [], 'last': 'Midha', 'suffix': ''},
#    {'first': 'J. R.', 'middle': [], 'last': 'Bosnik', 'suffix': ''}],
#   'abstract': None,
#   'year': 1984,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': '10.1115/1.3140682',
#   'venue': None,
#   'journal': 'Journal of Dynamic Systems Measurement and Control-transactions of The Asme',
#   'mag_id': '2074554620',
#   'mag_field_of_study': ['Mathematics'],
#   'outbound_citations': [],
#   'inbound_citations': ['53132385',
#    '124087766',
#    '149447397',
#    '6091382',
#    '133959917',
#    '124499085',
#    '119885622'],
#   'has_outbound_citations': False,
#   'has_inbound_citations': True,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:123626539'},
#  '123626553': {'title': 'On Electromagnetic Momentum',
#   'authors': [{'first': 'H. A.',
#     'middle': [],
#     'last': 'Wilson',
#     'suffix': ''}],
#   'abstract': None,
#   'year': 1920,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': '10.1103/PhysRev.16.17',
#   'venue': None,
#   'journal': 'Physical Review',
#   'mag_id': '2074425211',
#   'mag_field_of_study': ['Physics'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:123626553'},
#  '123626555': {'title': 'A neutron reflectometer on thermal neutrons with variable wavelength',
#   'authors': [{'first': 'A.',
#     'middle': ['B.'],
#     'last': 'Rubtsov',
#     'suffix': ''},
#    {'first': 'N.', 'middle': ['F.'], 'last': 'Miron', 'suffix': ''},
#    {'first': 'V.', 'middle': ['A.'], 'last': 'Somenkov', 'suffix': ''},
#    {'first': 'V.', 'middle': ['I.'], 'last': 'Bodnarchuk', 'suffix': ''},
#    {'first': 'S.', 'middle': ['P.'], 'last': 'Yaradaikin', 'suffix': ''}],
#   'abstract': 'A neutron reflectometer for investigating layered structures was developed as an additional model of the MOND diffractometer on the horizontal experimental channel no. 4 of the IR-8 reactor. The reflectometer was manufactured using standard tuning devices of linear and rotation translations. The experiments were carried out on model samples of layered structures of nanosized thickness. The technical characteristics of the reflectometer were determined and compared with those of the available reflectometric installations on stationary neutron sources.',
#   'year': 2011,
#   'arxiv_id': None,
#   'acl_id': None,
#   'pmc_id': None,
#   'pubmed_id': None,
#   'doi': '10.1134/S1027451011020169',
#   'venue': None,
#   'journal': 'Journal of Surface Investigation. X-ray, Synchrotron and Neutron Techniques',
#   'mag_id': '2073827291',
#   'mag_field_of_study': ['Physics'],
#   'outbound_citations': [],
#   'inbound_citations': [],
#   'has_outbound_citations': False,
#   'has_inbound_citations': False,
#   'has_pdf_parse': False,
#   's2_url': 'https://api.semanticscholar.org/CorpusID:123626555'}}

# %%
parsed_neighbors = []
for paper_id, specter_neighbors, specter_distances, hibert_neighbors, hibert_distances, overlap \
    in zip(paper_ids, specter_top5_neighbors, specter_top5_distances, hibert_top5_neighbors, hibert_top5_distances, overlaps):
    this_paper_info = {}
    this_paper_info['paper_id'] = paper_id
    this_paper_info['paper_info'] = build_paperstring(metadata, paper_id)
    for i in range(5):
        this_paper_info[f'specter_neighbor_{i+1}'] = build_paperstring(metadata, paper_ids[specter_neighbors[i]])
        this_paper_info[f'specter_distance_{i+1}'] = specter_distances[i]

        this_paper_info[f'hibert_neighbor_{i+1}'] = build_paperstring(metadata, paper_ids[hibert_neighbors[i]])
        this_paper_info[f'hibert_distance_{i+1}'] = hibert_distances[i]

        
    
    parsed_neighbors.append(this_paper_info)

# %%
parsed_neighbors[-1]
# Out:
# {'paper_id': '123621513',
#  'paper_info': 'Cold start characteristics study based on real time no emissions in an LPG SI engine, by Yingli Zu, Gong Li (2010).',
#  'specter_neighbor_1': "Do we need a new family of optical-NIR extinction laws?, by J. Apell'aniz (2012).",
#  'specter_distance_1': 0.2679466,
#  'hibert_neighbor_1': 'Aerodrome Warning Verification Using Quality Measurement of Contingency Table (Case Study in Jakarta and Tanjungpinang), by Mochammad Donny Anggoro, Diana Cahaya Siregar, Regina Dara Ninggar, Laksita Widomurti (2020).',
#  'hibert_distance_1': 0.00085014105,
#  'specter_neighbor_2': 'Understanding our Galaxy - key contributions from the Parkes telescope, by J. Caswell (2012).',
#  'specter_distance_2': 0.27512223,
#  'hibert_neighbor_2': 'Understanding our Galaxy - key contributions from the Parkes telescope, by J. Caswell (2012).',
#  'hibert_distance_2': 0.00094014406,
#  'specter_neighbor_3': 'Investigation ofant colonyalgorithm in multiple traffic flow environments, by A. Tizghadam, M. Hashemi, A. Leon-Garcia (2005).',
#  'specter_distance_3': 0.2866732,
#  'hibert_neighbor_3': 'In vivo/in vitro Studies of the Effects of the Type II Arabinogalactan Isolated from Maytenus ilicifolia Mart. ex Reissek on the Gastrointestinal Tract of Rats, by Cristiane Baggio, Cristina Freitas, André Twardowschy, Ana Santos, Bárbara Mayer, Francine Potrich, Thales Cipriani, Guilherme Sassaki, Marcello Iacomini, Maria Marques, Sonia Mesia-Vela (2012).',
#  'hibert_distance_3': 0.0009665489,
#  'specter_neighbor_4': 'On No-Node Solutions of the Lazer-McKenna Suspension Bridge Models, by Fanglei Wang, Kangbao Zhou (2015).',
#  'specter_distance_4': 0.29040354,
#  'hibert_neighbor_4': "Toward estimating the impact of changes in immigrants' insurance eligibility on hospital expenditures for uncompensated care, by Liana Castel, Justin Timbie, Veronica Sendersky, Lesley Curtis, Keith Feather, Kevin Schulman (2003).",
#  'hibert_distance_4': 0.0010882616,
#  'specter_neighbor_5': 'Calibration Method of an Ultrasonic System for Temperature Measurement, by Chao Zhou, Yueke Wang, Chunjie Qiao, Weihua Dai (2016).',
#  'specter_distance_5': 0.29325575,
#  'hibert_neighbor_5': 'Influence of galvanic vestibular stimulation on egocentric and object-based mental transformations, by Bigna Lenggenhager, Christophe Lopez, Olaf Blanke (2007).',
#  'hibert_distance_5': 0.0010961294}

# %%
output_csv = './project_dir/cse599/data/neighbors_output.csv'
with open(output_csv, 'w') as csvfile:
    fieldnames = parsed_neighbors[0].keys()
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for paper_neighbors in parsed_neighbors:
        writer.writerow(paper_neighbors)
